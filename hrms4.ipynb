# %%
import pandas as pd
import numpy as np
import datetime as dt
df1= pd.read_csv('/Users/Asmita/Downloads/Country.txt', sep="\t")
df2= pd.read_csv('/Users/Asmita/Downloads/State.txt', sep="\t")
df3= pd.read_csv('/Users/Asmita/Downloads/City.txt', sep="\t")
df4= pd.read_csv('/Users/Asmita/Downloads/Designation.txt', sep="\t")
df5= pd.read_csv('/Users/Asmita/Downloads/Employee.txt', sep="\t")
df6= pd.read_csv('/Users/Asmita/Downloads/Salary.txt', sep="\t")

# %% [markdown]
# 3.	Select first 3 records from country table in ascending order by country name.

# %%
df1.sort_values(by='Country_Name',ascending=True).head(3)
# Out:
#    Country_Id Country_Name
# 0           1  Afghanistan
# 1           2      Albania
# 2           3      Algeria

# %% [markdown]
# 4.	Select all employees whose first name starts with letter "a".

# %%
df5.loc[df5["Emp_First_Name"].str.startswith("R")]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 0               75 Calle Suerte          NaN              37            49
# 6  1019 Commonwealth Ave Apt301          NaN               3             7
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id    Emp_DOB  \
# 0           25    10034  1317778395           1         4  5/12/1978
# 6            7     2215  8572223333           1         3   1/1/1993
#
#   Emp_JoinDate  Emp_Active
# 0    3/22/2012           1
# 6     5/1/2014           1

# %%
df5.loc[df5["Emp_First_Name"].str.endswith("a")]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
#
#                 Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 1           533 Kosher Drive          NaN               5            13
# 2             122 Kobeya Ave          NaN               6            14
# 3  1001 Michigan Ave Apt3201          NaN              37            47
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id     Emp_DOB  \
# 1           13     3115  8553432022           1         2    8/1/1986
# 2           14    84430  6644227722           0         1  12/13/1988
# 3           15     1101  8572222210           0         6   11/1/1987
#
#   Emp_JoinDate  Emp_Active
# 1    1/27/2010           1
# 2     9/1/2013           0
# 3     2/1/2009           1

# %%
df5.loc[df5['Emp_Active']==0]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name    Emp_Address1  \
# 2       3        Yuriana             NaN      Hagasawa  122 Kobeya Ave
#
#   Emp_Address2  Emp_Country_Id  Emp_State_Id  Emp_City_Id  Emp_Zip  \
# 2          NaN               6            14           14    84430
#
#    Emp_Mobile  Emp_Gender  Desig_Id     Emp_DOB Emp_JoinDate  Emp_Active
# 2  6644227722           0         1  12/13/1988     9/1/2013           0

# %%
df5.loc[df5['Emp_Active'].isin(0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f250fdeac6f3> in <module>()
# ----> 1 df5.loc[df5['Emp_Active'].isin(0)]
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/series.py in isin(self, values)
#    2553
#    2554         """
# -> 2555         result = algorithms.isin(_values_from_object(self), values)
#    2556         return self._constructor(result, index=self.index).__finalize__(self)
#    2557
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/algorithms.py in isin(comps, values)
#     391         raise TypeError("only list-like objects are allowed to be passed"
#     392                         " to isin(), you passed a "
# --> 393                         "[{0}]".format(type(values).__name__))
#     394
#     395     if not isinstance(values, (ABCIndex, ABCSeries, np.ndarray)):
#
# ...

# %% [markdown]
# 7.	Select first name, last name, middle name of all employees and change the column names to First Name, Last Name, and Middle Name.

# %%
df5.rename(columns={'Emp_First_Name': 'First Name', 'Emp_Last_Name': 'Last Name', 'Emp_Middle_Name':'Middle Name'})
# Out:
#    Emp_Id First Name Middle Name  Last Name                  Emp_Address1  \
# 0       1    Ronaldo        Rome  Fabrizzio               75 Calle Suerte
# 1       2     Joshua         NaN        Kan              533 Kosher Drive
# 2       3    Yuriana         NaN   Hagasawa                122 Kobeya Ave
# 3       4    Venessa     Cameron   Katarina     1001 Michigan Ave Apt3201
# 4       5       Sahi         NaN       King          15 Gibbs Street Apt1
# 5       6       Chen         NaN       Chen       55 Beijing Road Apt1501
# 6   10002      Ricky      Russel  Riverland  1019 Commonwealth Ave Apt301
#
#                   Emp_Address2  Emp_Country_Id  Emp_State_Id  Emp_City_Id  \
# 0                          NaN              37            49           25
# 1                          NaN               5            13           13
# 2                          NaN               6            14           14
# 3                          NaN              37            47           15
# ...

# %%
df5
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN              37
# 1              533 Kosher Drive                          NaN               5
# 2                122 Kobeya Ave                          NaN               6
# 3     1001 Michigan Ave Apt3201                          NaN              37
# 4          15 Gibbs Street Apt1                          NaN              37
# ...

# %%
df5['Emp_Id'].count()
# Out:
# 7

# %%
df5['Emp_Middle_Name'].isnull().sum()
# Out:
# 4

# %%
df6=df5.copy()
df6['Emp_Middle_Name']=df6['Emp_Middle_Name'].fillna('Not Applicable')
df6[['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name']]
# Out:
#   Emp_First_Name Emp_Middle_Name Emp_Last_Name
# 0        Ronaldo            Rome     Fabrizzio
# 1         Joshua  Not Applicable           Kan
# 2        Yuriana  Not Applicable      Hagasawa
# 3        Venessa         Cameron      Katarina
# 4           Sahi  Not Applicable          King
# 5           Chen  Not Applicable          Chen
# 6          Ricky          Russel     Riverland

# %%
df5
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN              37
# 1              533 Kosher Drive                          NaN               5
# 2                122 Kobeya Ave                          NaN               6
# 3     1001 Michigan Ave Apt3201                          NaN              37
# 4          15 Gibbs Street Apt1                          NaN              37
# ...

# %%
df7=df5
df7['Full Name']=pd.concat([df7['Emp_First_Name'],df7['Emp_Middle_Name'].dropna(),df7['Emp_Last_Name']]).reindex_like(df7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-5a5071a800d1> in <module>()
#       1 df7=df5
# ----> 2 df7['Full Name']=pd.concat([df7['Emp_First_Name'],df7['Emp_Middle_Name'].dropna(),df7['Emp_Last_Name']]).reindex_like(df7)
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in reindex_like(self, other, method, copy, limit, tolerance)
#    2125                                        tolerance=tolerance)
#    2126
# -> 2127         return self.reindex(**d)
#    2128
#    2129     def drop(self, labels, axis=0, level=None, inplace=False, errors='raise'):
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    2424     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2425     def reindex(self, index=None, **kwargs):
# ...

# %%
 pd.merge(df5,df1, how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id', 1).sort_values(by='Country_Name',ascending=True)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 5       6           Chen  Not Applicable          Chen
# 6   10002          Ricky          Russel     Riverland
# 3       2         Joshua  Not Applicable           Kan
# 4       3        Yuriana  Not Applicable      Hagasawa
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       4        Venessa         Cameron      Katarina
# 2       5           Sahi  Not Applicable          King
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 5       55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               1
# 6  1019 Commonwealth Ave Apt301                          NaN               3
# 3              533 Kosher Drive                          NaN               5
# 4                122 Kobeya Ave                          NaN               6
# 0               75 Calle Suerte                          NaN              37
# ...

# %%
q1=pd.merge(df5,df3,how='inner',left_on='Emp_City_Id', right_on='City_Id').drop('City_Id',axis=1)
q1.loc[q1["City_Name"].str.startswith(("A","B","C","D"))]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi  Not Applicable          King
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 3     1001 Michigan Ave Apt3201          NaN              37            47
# 4          15 Gibbs Street Apt1          NaN              37            48
# 6  1019 Commonwealth Ave Apt301          NaN               3             7
#
#   Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id     Emp_DOB  \
# 3          15     1101  8572222210           0         6   11/1/1987
# 4          21     2215  6173338992           1         5  10/19/1977
# 6           7     2215  8572223333           1         3    1/1/1993
#
#   Emp_JoinDate  Emp_Active  State_Id  City_Name
# 3     2/1/2009           1      47.0  Anchorage
# 4     3/1/1999           1      48.0     Dallas
# ...

# %%
q1=pd.merge(df5,df3,how='inner',left_on='Emp_City_Id', right_on='City_Id').drop('City_Id',axis=1)
q1.loc[q1["City_Name"].isin(['Dallas','Algiers'])]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 4       5           Sahi  Not Applicable          King
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 4          15 Gibbs Street Apt1          NaN              37            48
# 6  1019 Commonwealth Ave Apt301          NaN               3             7
#
#   Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id     Emp_DOB  \
# 4          21     2215  6173338992           1         5  10/19/1977
# 6           7     2215  8572223333           1         3    1/1/1993
#
#   Emp_JoinDate  Emp_Active  State_Id City_Name
# 4     3/1/1999           1      48.0    Dallas
# 6     5/1/2014           1       7.0   Algiers

# %%
q1=pd.merge(df5,df1,how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id',axis=1)
q1=pd.merge(q1,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1['Emp_DOB'] = pd.to_datetime(q1['Emp_DOB'])
q1[['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Designation','Emp_DOB']].where((q1['Emp_DOB'] >'1/2/1984') & (q1['Emp_DOB'] < '1/3/1999'))
# Out:
#   Emp_First_Name Emp_Middle_Name Emp_Last_Name         Designation    Emp_DOB
# 0            NaN             NaN           NaN                 NaN        NaT
# 1        Venessa         Cameron      Katarina           Tech Lead 1987-11-01
# 2            NaN             NaN           NaN                 NaN        NaT
# 3         Joshua  Not Applicable           Kan  Software Developer 1986-08-01
# 4        Yuriana  Not Applicable      Hagasawa     Project Manager 1988-12-13
# 5            NaN             NaN           NaN                 NaN        NaT
# 6          Ricky          Russel     Riverland         Team Leader 1993-01-01

# %%
q1=pd.merge(df5,df1,how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id',axis=1)
q1=pd.merge(q1,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1['Emp_DOB'] = pd.to_datetime(q1['Emp_DOB'])
mask = (q1['Emp_DOB'] >='5/1/1978') & (q1['Emp_DOB'] <= '8/1/1986')
q1.loc[mask][['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Country_Name','Designation','Emp_DOB']]
# Out:
#   Emp_First_Name Emp_Middle_Name Emp_Last_Name   Country_Name  \
# 0        Ronaldo            Rome     Fabrizzio  United States
# 3         Joshua             NaN           Kan      Australia
# 5           Chen             NaN          Chen    Afghanistan
#
#           Designation    Emp_DOB
# 0    Business Analyst 1978-05-12
# 3  Software Developer 1986-08-01
# 5     Project Manager 1982-08-20

# %%
q1=pd.merge(df5,df1,how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id',axis=1)
q1=pd.merge(q1,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1=pd.merge(q1,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1.groupby(['Emp_ID']).apply(lambda x: (x.groupby('source').sort_values('count', ascending=False))].head(3))
# Out:
#     Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0        1        Ronaldo            Rome     Fabrizzio
# 1        1        Ronaldo            Rome     Fabrizzio
# 2        1        Ronaldo            Rome     Fabrizzio
# 3        4        Venessa         Cameron      Katarina
# 4        4        Venessa         Cameron      Katarina
# 5        5           Sahi             NaN          King
# 6        5           Sahi             NaN          King
# 7        5           Sahi             NaN          King
# 8        5           Sahi             NaN          King
# 9        2         Joshua             NaN           Kan
# 10       2         Joshua             NaN           Kan
# 11       2         Joshua             NaN           Kan
# 12       3        Yuriana             NaN      Hagasawa
# 13       3        Yuriana             NaN      Hagasawa
# 14       6           Chen             NaN          Chen
# 15       6           Chen             NaN          Chen
#
# ...

# %%
q1=pd.merge(df5,df1,how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id',axis=1)
q1=pd.merge(q1,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1=pd.merge(q1,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Country_Name','Designation','Emp_Salary']]
# Out:
#    Emp_First_Name Emp_Middle_Name Emp_Last_Name   Country_Name  \
# 2         Ronaldo            Rome     Fabrizzio  United States
# 11         Joshua             NaN           Kan      Australia
# 13        Yuriana             NaN      Hagasawa        Austria
# 4         Venessa         Cameron      Katarina  United States
# 8            Sahi             NaN          King  United States
# 15           Chen             NaN          Chen    Afghanistan
#
#            Designation  Emp_Salary
# 2     Business Analyst       85000
# 11  Software Developer       90000
# 13     Project Manager       56000
# 4            Tech Lead      185000
# 8      Design Engineer      156000
# 15     Project Manager       76000

# %%
q1=pd.merge(df5,df1,how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id',axis=1)
q1=pd.merge(q1,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1=pd.merge(q1,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q2=q1.loc[q1.groupby('Emp_Id').Emp_Salary.nlargest(1).index.get_level_values(1)]
mask=(q2['Emp_Salary']>=50000) & (q2['Emp_Salary']<=80000)
q2.loc[mask][['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Country_Name','Designation','Emp_Salary']]
# Out:
#    Emp_First_Name Emp_Middle_Name Emp_Last_Name Country_Name      Designation  \
# 13        Yuriana             NaN      Hagasawa      Austria  Project Manager
# 15           Chen             NaN          Chen  Afghanistan  Project Manager
#
#     Emp_Salary
# 13       56000
# 15       76000

# %%
 df5['Emp_First_Name'].str[:3]
# Out:
# 0    Ron
# 1    Jos
# 2    Yur
# 3    Ven
# 4    Sah
# 5    Che
# 6    Ric
# Name: Emp_First_Name, dtype: object

# %%
 df5['Emp_First_Name'].str.slice(0,3)
# Out:
# 0    Ron
# 1    Jos
# 2    Yur
# 3    Ven
# 4    Sah
# 5    Che
# 6    Ric
# Name: Emp_First_Name, dtype: object

# %%
df7=df5.copy()
df7['Emp_First_Name'].str.replace('a','$').str.replace('A','$')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-02029bd576c1> in <module>()
#       1 df7=df5.copy()
# ----> 2 df7[['Emp_First_Name'].str.replace('a','$').str.replace('A','$')]
#
# AttributeError: 'list' object has no attribute 'str'

# %%
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN              37
# 1              533 Kosher Drive                          NaN               5
# 2                122 Kobeya Ave                          NaN               6
# 3     1001 Michigan Ave Apt3201                          NaN              37
# 4          15 Gibbs Street Apt1                          NaN              37
# ...

# %%
df5['Emp_JoinDate'] = pd.to_datetime(df5['Emp_JoinDate'])
df7=df5
df7['Joined Year'] = df7['Emp_JoinDate'].dt.year
df7['Joined Month'] = df7['Emp_JoinDate'].dt.month
df7['Joined Day'] = df7['Emp_JoinDate'].dt.day
df7[['Emp_First_Name','Joined Year','Joined Month','Joined Day']]
# Out:
#   Emp_First_Name  Joined Year  Joined Month  Joined Day
# 0        Ronaldo         2012             3          22
# 1         Joshua         2010             1          27
# 2        Yuriana         2013             9           1
# 3        Venessa         2009             2           1
# 4           Sahi         1999             3           1
# 5           Chen         2006            10           1
# 6          Ricky         2014             5           1

# %%
df5.loc[df5['Emp_JoinDate'].dt.year == 2012]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name     Emp_Address1  \
# 0       1        Ronaldo            Rome     Fabrizzio  75 Calle Suerte
#
#   Emp_Address2  Emp_Country_Id  Emp_State_Id  Emp_City_Id  Emp_Zip  \
# 0          NaN              37            49           25    10034
#
#       ...      Desig_Id    Emp_DOB  Emp_JoinDate Emp_Active  Year  Month  Day  \
# 0     ...             4  5/12/1978    2012-03-22          1  2012      3   22
#
#    Joined Year  Joined Month  Joined Day
# 0         2012             3          22
#
# [1 rows x 22 columns]

# %%
q1=pd.merge(df5,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1.groupby('Designation').size().reset_index(name='Count')
# Out:
#           Designation  Count
# 0    Business Analyst      1
# 1     Design Engineer      1
# 2     Project Manager      2
# 3  Software Developer      1
# 4         Team Leader      1
# 5           Tech Lead      1

# %% [markdown]
# #27 Get designation wise average salaries from employee details table and order by Salary ascending.

# %%
q1=pd.merge(df5,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1=pd.merge(q1,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1.groupby(['Designation'])[['Emp_Salary']].mean().rename(columns={"Emp_Salary": "Average Salary per Designation"}).sort_values(by='Average Salary per Designation',ascending=True)
# Out:
#                     Average Salary per Designation
# Designation
# Software Developer                           55000
# Project Manager                              56750
# Business Analyst                             75000
# Design Engineer                             109800
# Tech Lead                                   145000

# %%
df7.groupby(['Joined Year','Joined Month'])[['Emp_Id']].count().rename(columns={"Emp_Id": "Number of Employees Joined"})
# Out:
#                           Number of Employees Joined
# Joined Year Joined Month
# 1999        3                                      1
# 2006        10                                     1
# 2009        2                                      1
# 2010        1                                      1
# 2012        3                                      1
# 2013        9                                      1
# 2014        5                                      1

# %%
df5[(~df5['Emp_Id'].isin(df6['Emp_Id']))]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 6  1019 Commonwealth Ave Apt301          NaN               3             7
#
#    Emp_City_Id  Emp_Zip     ...      Desig_Id   Emp_DOB  Emp_JoinDate  \
# 6            7     2215     ...             3  1/1/1993    2014-05-01
#
#   Emp_Active  Year  Month  Day  Joined Year  Joined Month  Joined Day
# 6          1  2014      5    1         2014             5           1
#
# [1 rows x 22 columns]

# %%
df5[~df5.Emp_Id.isin(df6.Emp_Id)]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 6  1019 Commonwealth Ave Apt301          NaN               3             7
#
#    Emp_City_Id  Emp_Zip     ...      Desig_Id   Emp_DOB  Emp_JoinDate  \
# 6            7     2215     ...             3  1/1/1993    2014-05-01
#
#   Emp_Active  Year  Month  Day  Joined Year  Joined Month  Joined Day
# 6          1  2014      5    1         2014             5           1
#
# [1 rows x 22 columns]

# %%
.any(axis=1)]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 1              533 Kosher Drive                          NaN               5
# 2                122 Kobeya Ave                          NaN               6
# 3     1001 Michigan Ave Apt3201                          NaN              37
# 4          15 Gibbs Street Apt1                          NaN              37
# 5       55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               1
# 6  1019 Commonwealth Ave Apt301                          NaN               3
#
# ...

# %%
q1=pd.merge(df5,df6,how='left',left_on='Emp_Id', right_on='Emp_Id')
q1[['Emp_Salary']]=q1[['Emp_Salary']].fillna(0)
q1.groupby(['Emp_Id','Emp_First_Name'])[['Emp_Salary']].sum().rename(columns={"Emp_Salary": "Sum of Salaryl"})
# Out:
#                        Sum of Salaryl
# Emp_Id Emp_First_Name
# 1      Ronaldo               225000.0
# 2      Joshua                165000.0
# 3      Yuriana                84000.0
# 4      Venessa               290000.0
# 5      Sahi                  439200.0
# 6      Chen                  143000.0
# 10002  Ricky                      0.0

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current Salary"})
# Out:
#     Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  Current Salary
# 2        1        Ronaldo            Rome     Fabrizzio           85000
# 5        2         Joshua             NaN           Kan           90000
# 7        3        Yuriana             NaN      Hagasawa           56000
# 9        4        Venessa         Cameron      Katarina          185000
# 13       5           Sahi             NaN          King          156000
# 15       6           Chen             NaN          Chen           76000

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current Salary"}).reset_index()
q1.loc[,'Emp_Salary']  q1[['Calculated Percentages']]=

# %%
q1=df5.copy()
q1['Emp_JoinDate'] = pd.to_datetime(q1['Emp_JoinDate'])
q1['Employee Total Working Days'] =dt.datetime.now().date() -  q1['Emp_JoinDate'] 
q1[['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_JoinDate','Employee Total Working Days']]
# Out:
#   Emp_First_Name Emp_Middle_Name Emp_Last_Name Emp_JoinDate  \
# 0        Ronaldo            Rome     Fabrizzio   2012-03-22
# 1         Joshua             NaN           Kan   2010-01-27
# 2        Yuriana             NaN      Hagasawa   2013-09-01
# 3        Venessa         Cameron      Katarina   2009-02-01
# 4           Sahi             NaN          King   1999-03-01
# 5           Chen             NaN          Chen   2006-10-01
# 6          Ricky          Russel     Riverland   2014-05-01
#
#   Employee Total Working Days
# 0                   2149 days
# 1                   2934 days
# 2                   1621 days
# 3                   3294 days
# 4                   6919 days
# 5                   4148 days
# 6                   1379 days

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1
# Out:
#     Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0        1        Ronaldo            Rome     Fabrizzio
# 1        1        Ronaldo            Rome     Fabrizzio
# 2        1        Ronaldo            Rome     Fabrizzio
# 3        2         Joshua             NaN           Kan
# 4        2         Joshua             NaN           Kan
# 5        2         Joshua             NaN           Kan
# 6        3        Yuriana             NaN      Hagasawa
# 7        3        Yuriana             NaN      Hagasawa
# 8        4        Venessa         Cameron      Katarina
# 9        4        Venessa         Cameron      Katarina
# 10       5           Sahi             NaN          King
# 11       5           Sahi             NaN          King
# 12       5           Sahi             NaN          King
# 13       5           Sahi             NaN          King
# 14       6           Chen             NaN          Chen
# 15       6           Chen             NaN          Chen
#
# ...

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q2=q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current Salary"}).reindex()
q3=q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nsmallest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Initial Salary"}).reindex()
q4=pd.merge(q2,q3,how='inner',left_on=['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name'], right_on=['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name'])
q4['Appraisal'] = q4['Current Salary'] - q4['Initial Salary']
q4.sort_values(by='Appraisal',ascending=False).head(1)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  Current Salary  \
# 3       4        Venessa         Cameron      Katarina          185000
#
#    Initial Salary  Appraisal
# 3          105000      80000

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q2=q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']]
q2[['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].sort_values(by='Emp_Salary',ascending=False).head(3).min()
# Out:
# Emp_First_Name    Joshua
# Emp_Last_Name        Kan
# Emp_Salary         90000
# dtype: object

# %%
apply(lambda x: x.nlargest(3).min())]
gb.bq_back_price.apply
.iloc[1])[df.bq_market_id]


df.groupby(['A'])['B','C'].apply(lambda x: x.nlargest(2, columns=['B'])

.rename(columns={"Emp_Salary": "Current Salary"}).reindex()
.'Current Salary'.nlargest(3).min(1)]
# Out:
#   File "<ipython-input-323-573aceb2fb6e>", line 1
#     apply(lambda x: x.nlargest(3).min())]
#                                         ^
# SyntaxError: invalid syntax

# %%
def average_salary(Emp_Id):
    #print (x)
    return (x.max() - x.min()) / 2


q1=pd.merge(df5,df6,how='left',left_on='Emp_Id', right_on='Emp_Id')
q1[['Emp_Salary']]=q1[['Emp_Salary']].fillna(0)
q1.groupby(['Emp_Id','Emp_First_Name'])[['Emp_Salary']].sum().rename(columns={"Emp_Salary": "Sum of Salaryl"})


df3=df1.groupby(['Country'])['Revenue'].apply(my_cool_func).reset_index()
print (df3)
  Country  Revenue
0  Canada    150.0
1      US    100.0

# %% [markdown]
# Select First name, Last name, Address, Country Name (by joining with country table), State Name (by joining with state table), City Name (by joining with city table),Mobile, and Designation name (by joining with designation table) of all employees .

# %%
q1=pd.merge(df5,df1,how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id',axis=1)
q1=pd.merge(q1,df2,how='inner',left_on='Emp_State_Id', right_on='State_Id').drop('State_Id',axis=1)
q1=pd.merge(q1,df3,how='inner',left_on='Emp_City_Id', right_on='City_Id')
q1=pd.merge(q1,df4,how='inner',left_on='Desig_Id', right_on='Desig_Id')
q1[['Emp_First_Name', 'Emp_Last_Name', 'Emp_Address1', 'Emp_Address2','Country_Name','State_Name','City_Name','Emp_Mobile','Designation']]
# Out:
#   Emp_First_Name Emp_Last_Name                  Emp_Address1  \
# 0        Ronaldo     Fabrizzio               75 Calle Suerte
# 1        Venessa      Katarina     1001 Michigan Ave Apt3201
# 2           Sahi          King          15 Gibbs Street Apt1
# 3         Joshua           Kan              533 Kosher Drive
# 4        Yuriana      Hagasawa                122 Kobeya Ave
# 5           Chen          Chen       55 Beijing Road Apt1501
# 6          Ricky     Riverland  1019 Commonwealth Ave Apt301
#
#                   Emp_Address2   Country_Name  State_Name   City_Name  \
# 0                          NaN  United States    New York    New York
# 1                          NaN  United States      Alaska   Anchorage
# 2                          NaN  United States       Texas      Dallas
# 3                          NaN      Australia    Victoria   Melbourne
# 4                          NaN        Austria  Burgenland  Eisenstadt
# ...

# %%
df5['Concatenated'] = df5['Emp_First_Name'] +' '+ df5['Emp_Middle_Name'].fillna('')+' '+df5['Emp_Last_Name']
df5
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN              37
# 1              533 Kosher Drive                          NaN               5
# 2                122 Kobeya Ave                          NaN               6
# 3     1001 Michigan Ave Apt3201                          NaN              37
# 4          15 Gibbs Street Apt1                          NaN              37
# ...

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current Salary"})
conditions = [[(q1['Emp_Id'] == 1),(q1['Emp_Id'] == 2),(q1['Emp_Id'] == 3)]]
choices = [0.10*q1['Current Salary'], [0.20*q1['Current Salary'], [0.15*q1['Current Salary']]
for i, row in q1.iterrows():
q1["Calculated Values"] = np.select(conditions, choices, default=[0.30*q1['Current Salary'])
print(q1)
# Out:
#   File "<ipython-input-369-40371f4369ff>", line 6
#     for i, row in q1.iterrows():
#       ^
# SyntaxError: invalid syntax

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q2=q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current Salary"})
q2['Calculated Values']=10000
q2['Calculated Values'][['Emp_Id'] == 1]=0.10*q2['Current Salary']
q2['Calculated Values'][['Emp_Id'] == 2]=0.20*q2['Current Salary']
q2['Calculated Values'][['Emp_Id'] == 3]=0.15*q2['Current Salary']
q2['Calculated Values'][['Emp_Id'] > 3]=0.30*q2['Current Salary']
q2
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#     777         try:
# --> 778             self.index._engine.set_value(values, key, value)
#     779             return
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value (pandas/_libs/index.c:4690)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value (pandas/_libs/index.c:4516)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# ...

# %%
df = pd.DataFrame({'Type':list('ABBC'), 'Set':list('ZZXY')})
conditions = [
    (df['Set'] == 'Z') & (df['Type'] == 'A'),
    (df['Set'] == 'Z') & (df['Type'] == 'B'),
    (df['Type'] == 'B')]
choices = ['yellow', 'blue', 'purple']
df['color'] = np.select(conditions, choices, default='black')
print(df)
# Out:
#   Set Type   color
# 0   Z    A  yellow
# 1   Z    B    blue
# 2   X    B  purple
# 3   Y    C   black

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q2=q1.groupby('Emp_Id',as_index=True)[['Emp_Salary']].mean()
q2
def Average_Salary(i): 
     if i in q2['Emp_Id']:
            q3=q2.loc['Emp_Id','Emp_First_Name','Emp_Last_Name','Emp_Salary']
    else :
         q3=print("Employee does not exist!")
return q3
# Out:
#   File "<ipython-input-444-7f6957e04fcd>", line 7
#     else :
#           ^
# IndentationError: unindent does not match any outer indentation level

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q2=q1.groupby('Emp_Id','Emp_First_Name','Emp_Last_Name')[['Emp_Salary']].mean()
q2
def Average_Salary(i): 
     if i in q2['Emp_Id']:
            q3=q2.loc['Emp_Id','Emp_First_Name','Emp_Last_Name','Emp_Salary']
    else :
        q3=print("Employee does not exist!")
return q3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-429-b0b57a74e8e9> in <module>()
# ----> 1 AVG_SAL(1)
#
# <ipython-input-426-2f2160e7f225> in AVG_SAL(Emp_Id)
#       2 q2=q1.groupby('Emp_Id',as_index=True)[['Emp_Salary']].mean()
#       3 q2
# ----> 4 def AVG_SAL(Emp_Id): return q2.loc[['Emp_Id','Emp_First_Name','Emp_Last_Name']]
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1539                     raise ValueError('Cannot index with multidimensional key')
#    1540
# ...

# %%
AVG_SAL(2)




,'Emp_First_Name'])

.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-415-2431e4bcba4c> in <module>()
# ----> 1 AVG_SAL(2)
#
# <ipython-input-413-a8f4bcc29bf7> in AVG_SAL(i)
#       2 q2=q1.groupby('Emp_Id',as_index=True)[['Emp_Salary']].mean()
#       3 q2
# ----> 4 def AVG_SAL(i): return q2.loc[['Emp_Id','Emp_First_Name','Emp_Last_Name','Emp_Salary']]
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1539                     raise ValueError('Cannot index with multidimensional key')
#    1540
# ...

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q2=q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current_Salary"})
def Per_Sal (q2):
    if q2['Emp_Id'] == 1:
        calc= q2['Current_Salary']*0.10
    elif q2['Emp_Id'] == 2:
         calc= q2['Current_Salary']*0.20
    elif q2['Emp_Id'] == 3:
         calc = q2['Current_Salary']*0.15
    else:
         calc = q2['Current_Salary']*0.3
    return calc

q2['Calculated_Percentages']=q2.apply(Per_Sal,axis=1)
q2[['Emp_Id','Emp_First_Name','Emp_Last_Name','Current_Salary','Calculated_Percentages']]
# Out:
#     Emp_Id Emp_First_Name Emp_Last_Name  Current_Salary  \
# 2        1        Ronaldo     Fabrizzio           85000
# 5        2         Joshua           Kan           90000
# 7        3        Yuriana      Hagasawa           56000
# 9        4        Venessa      Katarina          185000
# 13       5           Sahi          King          156000
# 15       6           Chen          Chen           76000
#
#     Calculated_Percentages
# 2                   8500.0
# 5                  18000.0
# 7                   8400.0
# 9                  55500.0
# 13                 46800.0
# 15                 22800.0

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id')
q1['Emp_Salary_Change_Year'] = pd.to_datetime(q1['Emp_Salary_Change_Year'])
q2=q1.loc[q1.groupby('Emp_Id').Emp_Salary_Change_Year.nlargest(1).index.get_level_values(1)][['Emp_Id','Emp_First_Name','Emp_Middle_Name','Emp_Last_Name','Emp_Salary']].rename(columns={"Emp_Salary": "Current_Salary"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-470-3c24b81f9fc3> in <module>()
#       4
#       5 for i in range(len(q2)):
# ----> 6     if q2['Emp_Id'] == 1:
#       7         q2['Calculated_Salary'] = q2['Current_Salary']*0.10
#       8     elif q2['Emp_Id'] == 2:
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id').groupby(['Emp_Id','Emp_First_Name','Emp_Last_Name'])[['Emp_First_Name','Emp_Last_Name','Emp_Salary']].mean().rename(columns={"Emp_Salary": "Average_Salary"})
def Average_Salary (id=1):
    return q1.loc[id]

# %%
Average_Salary(1)  q2=q1.loc[
# Out:
#                               Average_Salary
# Emp_First_Name Emp_Last_Name
# Ronaldo        Fabrizzio               75000

# %%
range(len(q2))
# Out:
# range(0, 6)

# %%
def Average_Salary (id=1):
    q1=pd.merge(df5,df6,how='inner',left_on='Emp_Id', right_on='Emp_Id').groupby(['Emp_Id','Emp_First_Name','Emp_Last_Name'])[['Emp_First_Name','Emp_Last_Name','Emp_Salary']].mean().rename(columns={"Emp_Salary": "Average_Salary"})
    return q1.loc[id]

# %%
Average_Salary(2)
# Out:
#                               Average_Salary
# Emp_First_Name Emp_Last_Name
# Joshua         Kan                     55000
