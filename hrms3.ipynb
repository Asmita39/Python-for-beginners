# %%
import pandas as pd

# %%
import numpy as np

# %%
df1= pd.read_csv('/Users/Asmita/Downloads/Country.txt', sep="\t")

# %%
print(df1)

# %%
df2= pd.read_csv('/Users/Asmita/Downloads/State.txt', sep="\t")

# %%
print(df2)

# %%
df3= pd.read_csv('/Users/Asmita/Downloads/City.txt', sep="\t")

# %%
print(df3)
# Out:
#     City_Id  State_Id      City_Name
# 0       1.0       1.0           Jurm
# 1       2.0       2.0       Abbakhsh
# 2       3.0       3.0         Baglan
# 3       4.0       4.0          Berat
# 4       5.0       5.0         Burrel
# 5       6.0       6.0         Durres
# 6       7.0       7.0        Algiers
# 7       8.0       8.0        Amsthas
# 8       9.0       9.0        Aboucha
# 9      10.0      10.0        Canillo
# 10     11.0      11.0         Ordino
# 11     12.0      12.0         Hobart
# 12     13.0      13.0      Melbourne
# 13     14.0      14.0     Eisenstadt
# 14     15.0      47.0      Anchorage
# 15     16.0      47.0      Fairbanks
# 16     17.0      47.0        College
# 17     18.0      47.0         Kodiak
# 18     19.0      47.0   Meadow Lakes
# 19     20.0      48.0        Houston
# 20     21.0      48.0         Dallas
# 21     22.0      48.0         Austin
# 22     24.0      48.0     Fort Worth
# 23     25.0      49.0       New York
# ...

# %%
df4= pd.read_csv('/Users/Asmita/Downloads/Designation.txt', sep="\t")

# %%
print(df4)
# Out:
#    Desig_Id         Designation   Desig_Description
# 0         1     Project Manager     Project Manager
# 1         2  Software Developer  Software Developer
# 2         3         Team Leader         Team Leader
# 3         4    Business Analyst    Business Analyst
# 4         5     Design Engineer     Design Engineer
# 5         6           Tech Lead           Tech Lead

# %%
df5= pd.read_csv('/Users/Asmita/Downloads/Employee.txt', sep="\t")

# %%
print(df5)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 1              533 Kosher Drive                          NaN              11
# 2                122 Kobeya Ave                          NaN               9
# 3     1001 Michigan Ave Apt3201                          NaN              11
# 4          15 Gibbs Street Apt1                          NaN              11
# ...

# %%
df6= pd.read_csv('/Users/Asmita/Downloads/Salary.txt', sep="\t")

# %%
print(df1.sort_values(by='Country_Name',ascending=True).head(3))
# Out:
#    Country_Id Country_Name
# 0           1  Afghanistan
# 1           2      Albania
# 2           3      Algeria

# %%
print(df5.loc[df5["Emp_First_Name"].str.startswith("R")])
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 0               75 Calle Suerte          NaN              37            49
# 6  1019 Commonwealth Ave Apt301          NaN               3             7
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id  Emp_DOB  \
# 0           25    10034  1317778395           1         4  00:00.0
# 6            7     2215  8572223333           1         3  00:00.0
#
#   Emp_JoinDate  Emp_Active
# 0      00:00.0           1
# 6      00:00.0           1

# %%
df5.loc[df5["Emp_First_Name"].str.endswith("a")]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
#
#                 Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 1           533 Kosher Drive          NaN               5            13
# 2             122 Kobeya Ave          NaN               6            14
# 3  1001 Michigan Ave Apt3201          NaN              37            47
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id  Emp_DOB  \
# 1           13     3115  8553432022           1         2  00:00.0
# 2           14    84430  6644227722           0         1  00:00.0
# 3           15     1101  8572222210           0         6  00:00.0
#
#   Emp_JoinDate  Emp_Active
# 1      00:00.0           1
# 2      00:00.0           0
# 3      00:00.0           1

# %%
df5.loc[df5["Emp_Active"]==0]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name    Emp_Address1  \
# 2       3        Yuriana             NaN      Hagasawa  122 Kobeya Ave
#
#   Emp_Address2  Emp_Country_Id  Emp_State_Id  Emp_City_Id  Emp_Zip  \
# 2          NaN               6            14           14    84430
#
#    Emp_Mobile  Emp_Gender  Desig_Id  Emp_DOB Emp_JoinDate  Emp_Active
# 2  6644227722           0         1  00:00.0      00:00.0           0

# %%
df5['Emp_Full_Name'] = df5['Emp_First_Name'] +" " df5['Emp_Middle_Name']+ " "+ df5['Emp_Last_Name']
# Out:
#   File "<ipython-input-59-8a0610880d81>", line 1
#     df5['Emp_Full_Name'] = df5['Emp_First_Name'] +" " df5['Emp_Middle_Name']+ " "+ df5['Emp_Last_Name']
#                                                         ^
# SyntaxError: invalid syntax

# %%
df5['Emp_Full_Name'] = (df5['Emp_First_Name', 'Emp_Middle_Name', 'Emp_Last_Name'].fillna('').values.tolist()).str.join('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: ('Emp_First_Name', 'Emp_Middle_Name', 'Emp_Last_Name')
#
# ...

# %%
print(df5.sort_values(by='Emp_First_Name',ascending=True).head(10))
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 5       6           Chen             NaN          Chen
# 1       2         Joshua             NaN           Kan
# 6   10002          Ricky          Russel     Riverland
# 0       1        Ronaldo            Rome     Fabrizzio
# 4       5           Sahi             NaN          King
# 3       4        Venessa         Cameron      Katarina
# 2       3        Yuriana             NaN      Hagasawa
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 5       55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               1
# 1              533 Kosher Drive                          NaN               5
# 6  1019 Commonwealth Ave Apt301                          NaN               3
# 0               75 Calle Suerte                          NaN              37
# 4          15 Gibbs Street Apt1                          NaN              37
# ...

# %%
df5.loc[df5["Emp_JoinDate"].str.startswith("2014")]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 6  1019 Commonwealth Ave Apt301          NaN              11            29
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id  \
# 6           39     2215  8572223333           1         3
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active
# 6  1993-01-01 00:00:00.000  2014-05-01 00:00:00.000           1

# %%
 df5.loc[df5['Emp_JoinDate'] < '2014-01-01']
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
#
#                 Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0            75 Calle Suerte                          NaN               2
# 1           533 Kosher Drive                          NaN              11
# 2             122 Kobeya Ave                          NaN               9
# 3  1001 Michigan Ave Apt3201                          NaN              11
# 4       15 Gibbs Street Apt1                          NaN              11
# 5    55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
# ...

# %%
df1.join(df2.set_index('Country_Id'),on='Country_Id',how='inner').join(df3.set_index('State_Id'),on='State_Id',how='inner')
# Out:
#     Country_Id   Country_Name State_Id  State_Name  City_Id      City_Name
# 0            1    Afghanistan        1  Badakhshan      1.0           Jurm
# 0            1    Afghanistan        2     Badghis      2.0       Abbakhsh
# 0            1    Afghanistan        3     Baghlan      3.0         Baglan
# 1            2        Albania        4       Berat      4.0          Berat
# 1            2        Albania        5       Diber      5.0         Burrel
# 1            2        Albania        6      Durres      6.0         Durres
# 2            3        Algeria        7       Adrar      7.0        Algiers
# 2            3        Algeria        8       Blida      8.0        Amsthas
# 2            3        Algeria        9      Tipaza      9.0        Aboucha
# 3            4        Andorra       10     Canillo     10.0        Canillo
# 3            4        Andorra       11      Ordino     11.0         Ordino
# ...

# %%
print(df1.join(df2.set_index('Country_Id'),on='Country_Id',how='inner').sort_values(by='State_Name',ascending=True))
# Out:
#     Country_Id   Country_Name  State_Id        State_Name
# 37          38         Uganda        51              Abim
# 2            3        Algeria         7             Adrar
# 16          17        Georgia        27            Ajaria
# 22          23          Japan        33             Akita
# 30          31          Qatar        41          Al Khawr
# 36          37  United States        47            Alaska
# 31          32         Russia        42             Altay
# 9           10          Chile        20           Atacama
# 39          40          Yemen        53              Ataq
# 13          14         France        24          Auvergne
# 38          39        Vietnam        52           Bac Can
# 0            1    Afghanistan         1        Badakhshan
# 0            1    Afghanistan         2           Badghis
# 0            1    Afghanistan         3           Baghlan
# 6            7         Brazil        16             Bahia
# ...

# %%
print(df5.join(df1.set_index('Country_Id'),on='Emp_Country_Id',how='inner').join(df2.set_index('State_Id'),on='Emp_State_Id',how='inner').join(df3.set_index('City_Id'),on='Emp_City_Id',how='inner').join(df4.set_index('Desig_Id'),on='Desig_Id',how='inner'))
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 2       3        Yuriana             NaN      Hagasawa
# 5       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 2           122 Kobeya Ave                          NaN               9
# 5  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip        ...          \
# 0             7           4    10034        ...
# 2            21          27    84430        ...
# 5             9           8    20033        ...
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active Country_Name  \
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000           1      Albania
# 2  1988-12-13 00:00:00.000  2013-09-01 00:00:00.000           0        China
# ...

# %%
print(df5.join(df1.set_index('Country_Id'),on='Emp_Country_Id').join(df2.set_index('State_Id'),on='Emp_State_Id').join(df3.set_index('City_Id'),on='Emp_City_Id').join(df4.set_index('Desig_Id'),on='Desig_Id'))
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 1              533 Kosher Drive                          NaN              11
# 2                122 Kobeya Ave                          NaN               9
# 3     1001 Michigan Ave Apt3201                          NaN              11
# 4          15 Gibbs Street Apt1                          NaN              11
# ...

# %%
pd.merge(df1,df2, how='inner',on='Country_Id').sort_values(by='State_Name',ascending=True)
# Out:
#     Country_Id   Country_Name  State_Id        State_Name
# 51          38         Uganda        51              Abim
# 6            3        Algeria         7             Adrar
# 26          17        Georgia        27            Ajaria
# 32          23          Japan        33             Akita
# 40          31          Qatar        41          Al Khawr
# 46          37  United States        47            Alaska
# 41          32         Russia        42             Altay
# 19          10          Chile        20           Atacama
# 53          40          Yemen        53              Ataq
# 23          14         France        24          Auvergne
# 52          39        Vietnam        52           Bac Can
# 0            1    Afghanistan         1        Badakhshan
# 1            1    Afghanistan         2           Badghis
# 2            1    Afghanistan         3           Baghlan
# 15           7         Brazil        16             Bahia
# ...

# %%
len(df5.index)
# Out:
# 7

# %%
pd.merge(df5,df1, how='inner',left_on='Emp_Country_Id', right_on='Country_Id').drop('Country_Id', axis=1).sort_values(by='Country_Name',ascending=True)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 6       6           Chen             NaN          Chen
# 5       3        Yuriana             NaN      Hagasawa
# 1       2         Joshua             NaN           Kan
# 2       4        Venessa         Cameron      Katarina
# 3       5           Sahi             NaN          King
# 4   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 6       55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
# 5                122 Kobeya Ave                          NaN               9
# 1              533 Kosher Drive                          NaN              11
# 2     1001 Michigan Ave Apt3201                          NaN              11
# ...

# %%
pd.merge(pd.merge(pd.merge(pd.merge(df5,df1, how='inner',left_on='Emp_Country_Id', right_on='Country_Id'),df2, how='inner',left_on='Emp_State_Id', right_on='State_Id'),df3, how='inner',left_on='Emp_City_Id', right_on='City_Id'),df4, how='inner',on='Desig_Id')
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       3        Yuriana             NaN      Hagasawa
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 1           122 Kobeya Ave                          NaN               9
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip        ...          Country_Id_x  \
# 0             7           4    10034        ...                     2
# 1            21          27    84430        ...                     9
# 2             9           8    20033        ...                     4
#
#    Country_Name  State_Id_x Country_Id_y State_Name  City_Id  State_Id_y  \
# 0       Albania           7            3      Adrar      4.0         4.0
# ...

# %%
pd.merge(pd.merge(pd.merge(pd.merge(df5,df1,left_on='Emp_Country_Id', right_on='Country_Id'),df2,left_on='Emp_State_Id', right_on='State_Id'),df3,left_on='Emp_City_Id', right_on='City_Id'),df4,on='Desig_Id')
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       3        Yuriana             NaN      Hagasawa
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 1           122 Kobeya Ave                          NaN               9
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip        ...          Country_Id_x  \
# 0             7           4    10034        ...                     2
# 1            21          27    84430        ...                     9
# 2             9           8    20033        ...                     4
#
#    Country_Name  State_Id_x Country_Id_y State_Name  City_Id  State_Id_y  \
# 0       Albania           7            3      Adrar      4.0         4.0
# ...

# %%
q1=pd.merge(df5,df1,left_on='Emp_Country_Id', right_on='Country_Id',how='inner').drop('Country_Id',axis=1)

# %%
print(q1)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       4        Venessa         Cameron      Katarina
# 3       5           Sahi             NaN          King
# 4   10002          Ricky          Russel     Riverland
# 5       3        Yuriana             NaN      Hagasawa
# 6       6           Chen             NaN          Chen
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 1              533 Kosher Drive                          NaN              11
# 2     1001 Michigan Ave Apt3201                          NaN              11
# 3          15 Gibbs Street Apt1                          NaN              11
# 4  1019 Commonwealth Ave Apt301                          NaN              11
# ...

# %%
q2= pd.merge(q1,df2,left_on='Emp_State_Id', right_on='State_Id').drop('State_Id',axis=1)
print(q2)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       4        Venessa         Cameron      Katarina
# 3       5           Sahi             NaN          King
# 4   10002          Ricky          Russel     Riverland
# 5       3        Yuriana             NaN      Hagasawa
# 6       6           Chen             NaN          Chen
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 1              533 Kosher Drive                          NaN              11
# 2     1001 Michigan Ave Apt3201                          NaN              11
# 3          15 Gibbs Street Apt1                          NaN              11
# 4  1019 Commonwealth Ave Apt301                          NaN              11
# ...

# %%
q3=pd.merge(q2,df3,left_on='Emp_City_Id', right_on='City_Id').drop('City_Id',axis=1)
print(q3)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       3        Yuriana             NaN      Hagasawa
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 1           122 Kobeya Ave                          NaN               9
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip    ...      Emp_Gender  Desig_Id  \
# 0             7           4    10034    ...               1         4
# 1            21          27    84430    ...               0         1
# 2             9           8    20033    ...               0         1
#
#                    Emp_DOB             Emp_JoinDate Emp_Active  Country_Name  \
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000          1       Albania
# ...

# %%
print(df5[['Emp_First_Name','Emp_Middle_Name','Emp_Last_Name']].replace(np.nan,'Not Applicable'))
# Out:
#   Emp_First_Name Emp_Middle_Name Emp_Last_Name
# 0        Ronaldo            Rome     Fabrizzio
# 1         Joshua  Not Applicable           Kan
# 2        Yuriana  Not Applicable      Hagasawa
# 3        Venessa         Cameron      Katarina
# 4           Sahi  Not Applicable          King
# 5           Chen  Not Applicable          Chen
# 6          Ricky          Russel     Riverland

# %%
print(df5[['Emp_First_Name'+' '+'Emp_Middle_Name'+' '+'Emp_Last_Name']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-ff31c811119f> in <module>()
# ----> 1 print(df5.loc[['Emp_First_Name'+' '+'Emp_Middle_Name'+' '+'Emp_Last_Name']])
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1539                     raise ValueError('Cannot index with multidimensional key')
#    1540
# -> 1541                 return self._getitem_iterable(key, axis=axis)
#    1542
#    1543             # nested tuple slicing
#
# ...

# %%
df5['concatenated'] = df5['Emp_First_Name'] +' '+ df5['Emp_Middle_Name']+' '+df5['Emp_Last_Name']
df5['concatenated']
# Out:
# 0      Ronaldo Rome Fabrizzio
# 1                         NaN
# 2                         NaN
# 3    Venessa Cameron Katarina
# 4                         NaN
# 5                         NaN
# 6      Ricky Russel Riverland
# Name: concatenated, dtype: object

# %%
df5
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi             NaN          King
# 5       6           Chen             NaN          Chen
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 1              533 Kosher Drive                          NaN              11
# 2                122 Kobeya Ave                          NaN               9
# 3     1001 Michigan Ave Apt3201                          NaN              11
# 4          15 Gibbs Street Apt1                          NaN              11
# ...

# %%
q1=pd.merge(df5,df3,how='inner',left_on='Emp_City_Id', right_on='City_Id').drop('City_Id',axis=1)
q1.loc[q1["City_Name"].str.startswith(("A","B","C","D"))]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id  \
# 0             7           4    10034  1317778395           1         4
# 2             9           8    20033  1988883321           0         1
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active  \
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000           1
# 2  1982-08-20 00:00:00.000  2006-10-01 00:00:00.000           1
#
#              concatenated  State_Id City_Name
# 0  Ronaldo Rome Fabrizzio       4.0     Berat
# 2                     NaN       8.0   Amsthas

# %%
q1
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       3        Yuriana             NaN      Hagasawa
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 1           122 Kobeya Ave                          NaN               9
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id  \
# 0             7           4    10034  1317778395           1         4
# 1            21          27    84430  6644227722           0         1
# 2             9           8    20033  1988883321           0         1
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active  \
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000           1
# ...

# %%
pd.to_datetime(df5['Emp_DOB'])
pd.to_datetime(df5['Emp_JoinDate'])
# Out:
# 0   2012-03-22
# 1   2010-01-27
# 2   2013-09-01
# 3   2009-02-01
# 4   1999-03-01
# 5   2006-10-01
# 6   2014-05-01
# Name: Emp_JoinDate, dtype: datetime64[ns]

# %%
df5.loc[df5["Emp_JoinDate"]'2014']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:14010)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-9979b1aa6720> in <module>()
# ----> 1 df5.loc[df5["Emp_JoinDate"]['2014']]
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ...

# %%
df5[(df5['Emp_DOB'] >='1984-2-1') & (df5['Emp_DOB'] <= '1986-3-1' )]A
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name      Emp_Address1  \
# 1       2         Joshua             NaN           Kan  533 Kosher Drive
#
#   Emp_Address2  Emp_Country_Id  Emp_State_Id  Emp_City_Id  Emp_Zip  \
# 1          NaN              11            34           54     3115
#
#    Emp_Mobile  Emp_Gender  Desig_Id                  Emp_DOB  \
# 1  8553432022           1         2  1986-08-01 00:00:00.000
#
#               Emp_JoinDate  Emp_Active concatenated
# 1  2010-01-27 00:00:00.000           1          NaN

# %%
pd.merge(df5,df3,how='inner',left_on='Emp_City_Id', right_on='City_Id').drop('City_Id',axis=1)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       3        Yuriana             NaN      Hagasawa
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 1           122 Kobeya Ave                          NaN               9
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Desig_Id  \
# 0             7           4    10034  1317778395           1         4
# 1            21          27    84430  6644227722           0         1
# 2             9           8    20033  1988883321           0         1
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active  \
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000           1
# ...
